# %%
import numpy as np
import tensorflow as tf
import random
from collections import deque
import gym

# %%
env = gym.make('CartPole-v1')

input_size = env.observation_space.shape[0]
output_size = env.action_space.n

dis = 0.9
REPLAY_MEMORY = 50000

# %%
class DQN:
    def __init__(self, input_size, output_size, name="network"):
        self.input_size = input_size
        self.output_size = output_size
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
        self.model = self.build_model()

    def build_model(self):
        model = tf.keras.Sequential([
            tf.keras.layers.InputLayer(input_shape=(self.input_size,)),
            tf.keras.layers.Dense(24, activation='relu'),
            tf.keras.layers.Dense(24, activation='relu'),
            tf.keras.layers.Dense(self.output_size),
        ])
        model.compile(optimizer=self.optimizer, loss='mse')
        return model

    def predict(self, state):
        state = np.reshape(state, [-1, self.input_size])
        return self.model(state)

    @tf.function
    def update(self, x_stack, y_stack):
        with tf.GradientTape() as tape:
            q_values = self.model(x_stack)
            loss = tf.reduce_mean(tf.square(y_stack - q_values))
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss

# %%
def replay_train(mainDQN, targetDQN, train_batch):
    x_stack = np.empty(0).reshape(0, input_size)
    y_stack = np.empty(0).reshape(0, output_size)

    for state, action, reward, next_state, done in train_batch:
        Q = mainDQN.predict(state).numpy()

        if done:
            Q[0, action] = reward
        else:
            Q[0, action] = reward + dis * np.max(targetDQN.predict(next_state))

        y_stack = np.vstack([y_stack, Q])
        x_stack = np.vstack([x_stack, state])

    y_stack = y_stack.astype(np.float32)

    return mainDQN.update(x_stack, y_stack)

# %%
def get_copy_var_ops(mainDQN, targetDQN):
    main_weights = mainDQN.model.get_weights()
    targetDQN.model.set_weights(main_weights)

# %%
def bot_play(mainDQN):
    s = env.reset()[0]
    reward_sum = 0

    while True:
        env.render()
        a = np.argmax(mainDQN.predict(s))
        s, reward, done, _, _ = env.step(a)
        reward_sum += reward

        if done:
            print("Total score: {}".format(reward_sum))
            break

# %%
def main():
    max_episodes = 5000
    replay_buffer = deque(maxlen=REPLAY_MEMORY)

    mainDQN = DQN(input_size, output_size, name="main")
    targetDQN = DQN(input_size, output_size, name="target")

    for episode in range(max_episodes):
        e = 1. / ((episode / 10) + 1)
        done = False
        step_count = 0

        state = env.reset()[0]

        while not done:
            if np.random.rand(1) < e:
                action = env.action_space.sample()
            else:
                action = np.argmax(mainDQN.predict(state))

            next_state, reward, done, _, _ = env.step(action)
            
            if done:
                reward = -100

            replay_buffer.append((state, action, reward, next_state, done))

            state = next_state
            step_count += 1
            if step_count > 10000:
                break

        print(f"Episode: {episode} steps: {step_count}")

        if episode % 10 == 1 and len(replay_buffer) >= 10:
            for _ in range(50):
                minibatch = random.sample(replay_buffer, 10)
                loss = replay_train(mainDQN, targetDQN, minibatch)
            print("Loss: ", loss)

            get_copy_var_ops(mainDQN, targetDQN)

        if episode % 50 == 0:
            bot_play(mainDQN)

    env.close()

# %%
main()
# Out:
# /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /opt/anaconda3/envs/gym/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# /opt/anaconda3/envs/gym/lib/python3.12/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym
# Loss:  tf.Tensor(0.20948148, shape=(), dtype=float32)
# Episode: 632 steps: 287
# Episode: 633 steps: 301
# Episode: 634 steps: 334
# Episode: 635 steps: 80
# Episode: 636 steps: 650
# Episode: 637 steps: 599
# Episode: 638 steps: 88
# Episode: 639 steps: 604
# Episode: 640 steps: 185
# Episode: 641 steps: 645
# Loss:  tf.Tensor(0.26124054, shape=(), dtype=float32)
# Episode: 642 steps: 240
# Episode: 643 steps: 655
# Episode: 644 steps: 537
# Episode: 645 steps: 85
# Episode: 646 steps: 306
# Episode: 647 steps: 118
# Episode: 648 steps: 102
# Episode: 649 steps: 602
# Episode: 650 steps: 96
# Total score: 1293.0
# Episode: 651 steps: 874
# Loss:  tf.Tensor(1.0081794, shape=(), dtype=float32)
# Episode: 652 steps: 724
# Episode: 653 steps: 3204
# Episode: 654 steps: 298
# Episode: 655 steps: 287
# Episode: 656 steps: 106
# Episode: 657 steps: 1624
# Episode: 658 steps: 99
# Episode: 659 steps: 922
# Episode: 660 steps: 207
# Episode: 661 steps: 568
# Loss:  tf.Tensor(0.768809, shape=(), dtype=float32)
# Episode: 662 steps: 63
# Episode: 663 steps: 75
# Episode: 664 steps: 446
# Episode: 665 steps: 192
# Episode: 666 steps: 355
# Episode: 667 steps: 100
# Episode: 668 steps: 168
# Episode: 669 steps: 1873
# Episode: 670 steps: 274
# Episode: 671 steps: 71
# Loss:  tf.Tensor(0.29978508, shape=(), dtype=float32)
# Episode: 672 steps: 285
# Episode: 673 steps: 768
# Episode: 674 steps: 208
# Episode: 675 steps: 961
# Episode: 676 steps: 395
# Episode: 677 steps: 1495
# Episode: 678 steps: 71
# Episode: 679 steps: 184
# Episode: 680 steps: 1892
# Episode: 681 steps: 94
# Loss:  tf.Tensor(0.075266086, shape=(), dtype=float32)
# Episode: 682 steps: 893
# Episode: 683 steps: 1288
# Episode: 684 steps: 1154
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 main()
#
# Cell In[7], line 19, in main()
#      17     action = env.action_space.sample()
#      18 else:
# ---> 19     action = np.argmax(mainDQN.predict(state))
#      21 next_state, reward, done, _, _ = env.step(action)
#      23 if done:
#
# Cell In[3], line 20, in DQN.predict(self, state)
#      18 def predict(self, state):
#      19     state = np.reshape(state, [-1, self.input_size])
# ---> 20     return self.model(state)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/models/sequential.py:212, in Sequential.call(self, inputs, training, mask)
#     210 def call(self, inputs, training=None, mask=None):
#     211     if self._functional:
# --> 212         return self._functional.call(inputs, training=training, mask=mask)
#     214     # Fallback: Just apply the layer sequence.
#     215     # This typically happens if `inputs` is a nested struct.
#     216     for layer in self.layers:
#     217         # During each iteration, `inputs` are the inputs to `layer`, and
#     218         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     219         # end of each iteration `inputs` is set to `outputs` to prepare for
#     220         # the next layer.
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/models/functional.py:175, in Functional.call(self, inputs, training, mask)
#     173         if mask is not None:
#     174             x._keras_mask = mask
# --> 175 outputs = self._run_through_graph(
#     176     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     177 )
#     178 return unpack_singleton(outputs)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/models/functional.py:560, in operation_fn.<locals>.call(*args, **kwargs)
#     554 if (
#     555     hasattr(operation, "_call_has_training_arg")
#     556     and operation._call_has_training_arg
#     557     and training is not None
#     558 ):
#     559     kwargs["training"] = training
# --> 560 return operation(*args, **kwargs)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/layers/core/dense.py:146, in Dense.call(self, inputs, training)
#     144 x = ops.matmul(inputs, self.kernel)
#     145 if self.bias is not None:
# --> 146     x = ops.add(x, self.bias)
#     147 if self.activation is not None:
#     148     x = self.activation(x)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/ops/numpy.py:168, in add(x1, x2)
#     166 if any_symbolic_tensors((x1, x2)):
#     167     return Add().symbolic_call(x1, x2)
# --> 168 return backend.numpy.add(x1, x2)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/backend/tensorflow/sparse.py:493, in elementwise_binary_union.<locals>.wrap_elementwise_binary_union.<locals>.sparse_wrapper(x1, x2)
#     490 elif isinstance(x2, tf.IndexedSlices):
#     491     # x2 is an IndexedSlices, densify.
#     492     x2 = tf.convert_to_tensor(x2)
# --> 493 return func(x1, x2)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/backend/tensorflow/numpy.py:38, in add(x1, x2)
#      36 x1 = convert_to_tensor(x1, dtype)
#      37 x2 = convert_to_tensor(x2, dtype)
# ---> 38 return tf.add(x1, x2)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/ops/math_ops.py:3915, in add(x, y, name)
#    3913 with ops.name_scope(name, "Add", [x]) as name:
#    3914   x = ops.convert_to_tensor(x, name="x")
# -> 3915   y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#    3916   if x.dtype == dtypes.string:
#    3917     return gen_math_ops.add(x, y, name=name)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:77, in Variable.__tf_tensor__(self, dtype, name)
#      76 def __tf_tensor__(self, dtype=None, name=None):
# ---> 77     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)
#     159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/ops/resource_variable_ops.py:2375, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2374 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2375   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/ops/resource_variable_ops.py:1621, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1619   return self.read_value().op.inputs[0]
#    1620 else:
# -> 1621   return self.value()
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/ops/resource_variable_ops.py:656, in BaseResourceVariable.value(self)
#     654   return self._cached_value
#     655 with ops.colocate_with(None, ignore_existing=True):
# --> 656   return self._read_variable_op()
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/ops/resource_variable_ops.py:841, in BaseResourceVariable._read_variable_op(self, no_copy)
#     839       result = read_and_set_handle(no_copy)
#     840 else:
# --> 841   result = read_and_set_handle(no_copy)
#     843 if not context.executing_eagerly():
#     844   # Note that if a control flow context is active the input of the read op
#     845   # might not actually be the handle. This line bypasses it.
#     846   record.record_operation(
#     847       "ReadVariableOp", [result], [self.handle],
#     848       backward_function=lambda x: [x],
#     849       forward_function=lambda x: [x])
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/ops/resource_variable_ops.py:831, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     829 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     830   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 831 result = gen_resource_variable_ops.read_variable_op(
#     832     self.handle, self._dtype)
#     833 _maybe_set_handle_data(self._dtype, self.handle, result)
#     834 return result
#
# File /opt/anaconda3/envs/gym/lib/python3.12/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:534, in read_variable_op(resource, dtype, name)
#     532 if tld.is_eager:
#     533   try:
# --> 534     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536     return _result
#     537   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
